# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np


def func(x):
    return 0.5 * x + 0.2 * x ** 2 - 0.1 * x ** 3


def df(x):
    return -0.3*x**2 + 0.4*x + 0.5


coord_x = np.arange(-5.0, 5.0, 0.1) # значения по оси абсцисс
coord_y = func(coord_x) # значения по оси ординат (значения функции)

# здесь продолжайте программу
lmd = 0.01
x0 = -4
N = 200

for i in range(N):
    x0 = x0 - lmd * df(x0)
x = x0
x
# Out:
# -1.0758987284245605

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
import numpy as np

# исходная функция, которую нужно аппроксимировать моделью a(x)
def func(x):
    return 0.1 * x**2 - np.sin(x) + 5.

# функция градиента
def dQ(x, w): 
    return 2/n * (w.T @ x - coord_y) @ x.T

coord_x = np.arange(-5.0, 5.0, 0.1) # значения по оси абсцисс [-5; 5] с шагом 0.1
coord_y = func(coord_x) # значения функции по оси ординат

sz = len(coord_x)	# количество значений функций (точек)
eta = np.array([0.1, 0.01, 0.001, 0.0001]) # шаг обучения для каждого параметра w0, w1, w2, w3
w = np.array([0., 0., 0., 0.]).T # начальные значения параметров модели
N = 200 # число итераций градиентного алгоритма
n = len(coord_x)

X = np.array([[1, x, x**2, x**3] for x in coord_x]).T
Y = coord_y

for i in range(N):
    w = w - eta * dQ(X, w)

# показатель качества (квадратичная функция)
Q = 1/n * sum([(w.T @ x - coord_y[j]) ** 2 for j, x in enumerate(X.T)])
Q
# Out:
# 0.1306146393607371

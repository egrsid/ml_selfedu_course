# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import torch

x = torch.tensor([1, 100, 50, 2, 500], dtype=torch.float32).T
w = torch.tensor([2.5, -0.8, 3, 2, -0.15], dtype=torch.float32).T

a = w.T @ x
1 - torch.sigmoid(a).item()
# Out:
# 0.18242555856704712

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
from itertools import combinations

x = np.array([1, 190, 70, 1, 300]).T

for i in range(-10, 10):
    for j in range(-10, 10):
        for k in range(-10, 10):
            for p in range(-10, 10):
                for e in range(-10, 10):
                    w = np.array([i, j, k, p, e]).T
                    M = w.T @ x * (-1)
                    if M == 1:
                        print(w)
# Out:
# [-10 -10  -7  -1   8]
# [-10  -9   3   9   5]
# [-10  -8  -4   9   6]
# [-10  -8   9  -1   3]
# [-10  -7   2  -1   4]
# [-10  -6  -5  -1   5]
# [-10  -5   5   9   2]
# [-10  -4  -2   9   3]
# [-10  -3  -9   9   4]
# [-10  -3   4  -1   1]
# [-10  -2  -3  -1   2]
# [-10  -1 -10  -1   3]
# [-10  -1   7   9  -1]
# [-10   0   0   9   0]
# [-10   1  -7   9   1]
# [-10   1   6  -1  -2]
# [-10   2  -1  -1  -1]
# [-10   3  -8  -1   0]
# [-10   3   9   9  -4]
# [-10   4   2   9  -3]
# [-10   5  -5   9  -2]
# [-10   5   8  -1  -5]
# [-10   6   1  -1  -4]
# [-10   7  -6  -1  -3]
# [-10   8   4   9  -6]
# [-10   9  -3   9  -5]
# [ -9 -10  -7  -2   8]
# [-9 -9  3  8  5]
# [-9 -8 -4  8  6]
# [-9 -8  9 -2  3]
# [-9 -7  2 -2  4]
# [-9 -6 -5 -2  5]
# [-9 -5  5  8  2]
# [-9 -4 -2  8  3]
# [-9 -3 -9  8  4]
# [-9 -3  4 -2  1]
# [-9 -2 -3 -2  2]
# [ -9  -1 -10  -2   3]
# [-9 -1  7  8 -1]
# [-9  0  0  8  0]
# [-9  1 -7  8  1]
# [-9  1  6 -2 -2]
# [-9  2 -1 -2 -1]
# [-9  3 -8 -2  0]
# [-9  3  9  8 -4]
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np

# здесь записывайте вектор
w = np.array([20, -1, 3, 5, -0.15])
y = 1
p = 0.5

M = -np.log(1/p - 1)

x = 1/w

x *= M / (w * y)
# Out:
# array([-0., -0., -0., -0., -0.])

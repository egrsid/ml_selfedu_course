# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
import numpy as np

X = [(230, 180), (210, 190), (200, 200), (240, 195), (205, 167), (220, 155), (230, 155), (250, 175), (242, 210), (260, 190), (74, 96), (103, 82), (135, 76), (162, 79), (184, 97), (206, 111), (231, 118), (251, 118), (275, 110), (380, 70), (298, 86), (320, 68), (344, 62), (376, 61), (403, 75), (254, 80), (219, 85), (288, 66), (260, 92), (201, 76), (162, 66), (127, 135), (97, 143), (83, 160), (82, 177), (88, 199), (105, 205), (135, 208), (151, 198), (157, 169), (153, 152), (117, 158), (106, 168), (106, 185), (123, 188), (125, 171), (139, 163), (139, 183), (358, 127), (328, 132), (313, 146), (300, 169), (300, 181), (308, 197), (326, 206), (339, 209), (370, 199), (380, 184), (380, 147), (343, 154), (329, 169), (332, 184), (345, 185), (363, 159), (361, 177), (344, 169), (311, 175), (351, 89), (134, 96)]

X = np.array(X)

def R(x, a, b, c):
    return x[1] >= a and x[0] >= b and x[0] < c

th = [120, 200, 300] 
X2 = [tuple(xi) for xi in X if R(xi, *th)]

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
import numpy as np

x_test = [(9, 6), (2, 4), (-3, -1), (3, -2), (-3, 6), (7, -3), (6, 2)]

# здесь продолжайте программу
x = np.array([[1, x1, x2] for x1, x2 in x_test])
w = np.array([-14/5, 7/5, -1])
predict = np.int32(np.sign(w @ x.T))
predict
# Out:
# array([ 1, -1, -1,  1, -1,  1,  1], dtype=int32)

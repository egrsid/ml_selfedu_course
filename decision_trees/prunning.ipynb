# %% [markdown]
# ![image.png](attachment:image.png)

# %%
v1, v3, v4, v5 = 120, 75, 67, 112

qv1 = v1 / sum([v1, v3, v4, v5])
qv3 = v3 / sum([v1, v3, v4, v5])
qv2 = 1 - qv1 - qv3

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
v4_count = 67
v5_count = 112
v2_count = v4_count + v5_count

v4 = [60, 7]
v5 = [12, 100]

pv4 = v4[0] / sum(v4)
pv5 = v5[0] / sum(v5)
qv2v4 = v4_count / v2_count
qv2v5 = v5_count / v2_count

Pv2 = pv4 * qv2v4 + pv5 * qv2v5
Pv2
# Out:
# 0.40223463687150834
